# %%
import pprint
import numpy as np
import seaborn as sns

from utils import Utils
from pipeline import HsiPipeline
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
folder = '/Users/Usuario/Documents/Pipeline HSI/HyperSI/Plastico B'
samples = Utils.load_samples(folder)
samples_dict = Utils.get_dict(samples=Utils.load_samples(folder))

pprint.pprint(samples)


#Aqui eu tenho a lista com o nome delas = X[sample]

#get_xy tenho as variaveis de acordo com cada na posicao ind - como passar a atribuicao aqui 
#Ou tem como acessar X de outro arquivo?
# Out:
# ['Bacillusscereus_14579_Plastico_B_180926-092335',
#  'Coryniumbacteriumglutaminum_13032_Plastico_B_180926-093210',
#  'Enterobacteaerogenes_13048_Plastico_B_Contaminado_180926-102747',
#  'Enterococcusfaecalis_29212_Plastico_B_180926-093958',
#  'Klebsielapneumonial_700603_Plastico_B_180926-105913',
#  'Micrococcusluteus_9341_Plastico_B_180926-093534',
#  'Pseudomonasaeoruginosas_9027_Plastico_B_180926-104046',
#  'Salmonellaspp_10708_Plastico_B_180926-104803',
#  'Serratiamarcences_14765_Plastico_B_180926-105123']

# %%
pipeline = HsiPipeline(data_folder=folder, samples=samples_dict)

# %%
pipeline.visualize_images()

# %%
pipeline.get_spectrals(case=0, spectral_range=(1, 241))
# Out:
# c:\Users\Usuario\Documents\Pipeline HSI\HyperSI\pipeline.py:347: UserWarning: Legend does not support [<matplotlib.lines.Line2D object at 0x0000023A9F153520>] instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   legend = fig.legend(
# c:\Users\Usuario\Documents\Pipeline HSI\HyperSI\pipeline.py:347: UserWarning: Legend does not support [<matplotlib.lines.Line2D object at 0x0000023A9F145430>] instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   legend = fig.legend(
# c:\Users\Usuario\Documents\Pipeline HSI\HyperSI\pipeline.py:347: UserWarning: Legend does not support [<matplotlib.lines.Line2D object at 0x0000023A9F153910>] instances.
# A proxy artist may be used instead.
# ...
